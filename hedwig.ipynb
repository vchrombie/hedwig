# %%
# !pip -V
# !pip install nltk
# Out:
# pip 19.1 from /home/vchrombie/anaconda3/lib/python3.7/site-packages/pip (python 3.7)
# Requirement already satisfied: nltk in /home/vchrombie/anaconda3/lib/python3.7/site-packages (3.4)
# Requirement already satisfied: six in /home/vchrombie/anaconda3/lib/python3.7/site-packages (from nltk) (1.11.0)
# Requirement already satisfied: singledispatch in /home/vchrombie/anaconda3/lib/python3.7/site-packages (from nltk) (3.4.0.3)

# %%
import re
import json
import string

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import sklearn.linear_model as sk
from sklearn import preprocessing
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
from sklearn.model_selection import KFold
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC, SVC

from nltk import SnowballStemmer

# %%
def tokenize(data):
    """ Tokenize tweets """
    stemmer = SnowballStemmer("english")
    stop_words = text.ENGLISH_STOP_WORDS
    temp = data
    regex = re.compile('[%s]' % re.escape(string.punctuation))
    temp = regex.sub(' ', temp)
    temp = "".join(b for b in temp if ord(b) < 128)
    temp = temp.lower()
    words = temp.split()
    no_stop_words = [w for w in words if not w in stop_words]
    stemmed = [stemmer.stem(item) for item in no_stop_words]

    return stemmed

# %%
def reduce_by_location(data):
    """ Reduces dataset to only contain tweets with location
        marked as either WA or MA """
    temp = data[(data.location.str.contains(r'[.]+ WA$'))
            | (data.location.str.contains(r'[.]+ MA$'))
            | (data.location.str.contains('Boston'))
            | (data.location.str.contains('Seattle'))
            | (data.location.str.contains(r'[.]+ Washington\s'))
            | (data.location.str.contains('Massachusetts'))]
    
    return temp

# %%
def map_locations(data):
    """ Creates target variables 1: for WA and 0: MA """
    targets = []
    data.location.apply(lambda x: x.encode('utf-8').strip())
    for location in data.location:
        if (r'[.]+ WA$' in location) or ('Seattle' in location) or (r'[.]+ Washington\s' in location):
            targets.append(1)
        else:
            targets.append(0)
    return np.array(targets)

# %%
def balance_datasets(data, targets):
    """ Balances datasets by selecting random points from
        the minority class """
    new_data = data.copy()
    if (len(targets[targets==0])) > (len(targets[targets==1])):
        points_needed = len(targets[targets==0]) - len(targets[targets==1])
        indices = np.where(targets == 1)
    else:
        points_needed = len(targets[targets==1]) - len(targets[targets==0])
        indices = np.where(targets == 0)

    np.random.shuffle(indices)
    indices = np.resize(indices, points_needed)
    new_data = new_data.append(data.iloc[indices])
    targets_to_add = targets[indices]
    new_targets = np.concatenate([targets, targets_to_add])
    return new_data, new_targets

# %%
DATA_FOLDER = 'tweet_data/'
filename = 'tweets_#superbowl.txt'

# %%
# Collect tweets from superbowl
count=0

tweets_ = []
with open(filename, 'r') as f:
    for row in f:
        if(count>80000):
            break
        jrow = json.loads(row)
        d = {
            'tweet': jrow['title'],
            'location': jrow['tweet']['user']['location']
        }
        tweets_.append(d)
        count=count+1

# %%
all_data = pd.DataFrame(tweets_)
all_data
# Out:
#                              location  \
# 0                #Seahawks #Mariners
# 1
# 2                          k-town Ak.
# 3                              Brazil
# 4                                Iowa
# 5           http://ask.fm/lKatzPerryl
# 6                             Cloud 9
# 7                       LATINOAMÉRICA
# 8       Westcoast right near da beach
# 9                          Boston, MA
# 10     Gran Canaria Madrid Londres LA
# 11                 Phoenix Valleywide
# 12
# 13                            Seattle
# 14                            the USA
# 15                   Bogota, Colombia
# 16                   Victor, New York
# 17                 Tampa Bay, Florida
# 18                        Memphis, TN
# 19                         London, UK
# 20                             Canada
# 21                          Worldwide
# 22                     Huntsville, AL
# 23
# 24
# 25                  So. Cal and Vegas
# 26                        Phoenix, AZ
# 27
# 28
# 29                     High Point, NC
# ...                               ...
# 59971                             USA
# 59972                  Providence, RI
# 59973             Northern California
# 59974   iPhone: 36.298397,-115.210976
# 59975                Spokane, WA, USA
# 59976                         Phoenix
# 59977
# 59978                 Noblesville, IN
# 59979
# 59980     Just far enough west of NYC
# 59981                      The Battle
# 59982                    Greater #yyj
# 59983
# 59984
# 59985         Flying High in the 5280
# 59986             Kingston, ON Canada
# 59987                        Virginia
# 59988      Acres Homes, HOUstoner, Tx
# 59989                     Seattle, WA
# 59990      Acres Homes, HOUstoner, Tx
# 59991                        New York
# 59992                   INTERNATIONAL
# 59993      Acres Homes, HOUstoner, Tx
# 59994
# 59995                          U.S.A.
# 59996                        New York
# 59997
# 59998
# 59999          hidden muffin lair, NC
# 60000
#
#                                                    tweet
# 0      I'm so excited the road to #SuperBowlXLIX will...
# 1      At http://t.co/Vd0RWOeAed -- #Seahawks #12thMA...
# 2      You been 12ed pass it on #SeahawkNation #LOB #...
# 3      27 days to the SuperBowl 🏈🏈\n#Katyperry #KatyC...
# 4      Check out the cool event that  #budlight has p...
# 5      #SuperBowl2015 #Halftime 🏈🎉 http://t.co/qk8Wew...
# 6      Lenny Kravitz acompañará a Katy Perry en el #H...
# 7      #AlertaQRP NFL anuncia que Katy Perry estará a...
# 8      So this official OMG Super Bowl #prediction \n...
# 9      Our @ButchStearns talked #Patriots w/3X #Super...
# 10     @katyperry invitará a tocar la guitarra a @Len...
# 11     #SUPERFEST2k15 #superbowlweekend #superbowlXLI...
# 12     We've got updated #SuperBowl odds:\n#Seahawks ...
# 13     #MondayMotivation #GOHAWKS #SEAHAWKS #superbow...
# 14     And it begins #SuperBowl2015 #hype #downtown #...
# 15     Y SOLO FALTAN 12 DÍAS PARA (tal vez) LA MEJOR ...
# 16     Packers v. Seahawks, Colts v. Patriots. Who wi...
# 17     Make this delicious Barbecued Meatball Sauce f...
# 18     Celebrate #SuperBowlXLIX with a Home Team Hudd...
# 19     #KatyPerry set to be joined by Lenny Kravitz o...
# 20     1M PC Plus points to won! Purchase PepsiCo Pro...
# 21     .@LennyKravitz will be joining @katyperry onst...
# 22     Check out this crop circle art - this and more...
# 23     @space_needle #Tophawk #SuperBowlXLIX #12 http...
# 24     Já somos mais de 80 confirmados para assistir ...
# 25     Big Game Central at @LVSuperBook is just 19 da...
# 26     Grand opening of the Valley Overlook space @Sh...
# 27     Randall Cunningham Collection, Vintage Jerseys...
# 28     Sill high from #NFC west win! #Seahawks #Super...
# 29     @ravenmt_ @AVRevolution  You didn't give them ...
# ...                                                  ...
# 59971  @garciag_sandy @laluzjose y dice un Alcande qu...
# 59972  @JoeyJengle @EBuco Don't poke the bear! Or the...
# 59973  Speechless over how awesome this is! How to Ma...
# 59974  Put the #Colts in #SuperBowlXLIX #DeflatedBall...
# 59975  As long as the #Seahawks win the #SuperBowl, I...
# 59976  RT #Ecuador busca atraer turismo mediante #Sup...
# 59977  This is me, just waiting #superbowl49 #patriot...
# 59978  I should say a Belichick suspension for #Super...
# 59979  Just saw @TajhB10 at a red light. About to sho...
# 59980  @kmulford1 only 1 way to settle it: @EAMaddenN...
# 59981  #inflategate #deflategate #tombrady #patriots ...
# 59982  Love how my local @saveonfoods #Saanich Plaza ...
# 59983  #Seahawks #SuperBowlIXLIX Jobless father of 2 ...
# 59984  #deflategate Cheaters do not deserve to win. R...
# 59985  I feel alot of people would like to see the pa...
# 59986  Hey @nfl looks like my dog is using the @Patri...
# 59987  https://t.co/vwiYp1c3HO @coronaextrausa #Super...
# 59988  #SuperBowlXLIX @ #HughesHangar Feb 1st | $0.50...
# 59989  Looking for a great winter hike to do in the #...
# 59990  #SuperBowlXLIX @ #HughesHangar Feb 1st | $0.50...
# 59991  @TheView The #Patriots should be stripped of t...
# 59992  #arizona I'll see you guys this #Saturday for ...
# 59993  #SuperBowlXLIX @ #HughesHangar Feb 1st | $0.50...
# 59994  #AaronRodgers doesn't think god cares about fo...
# 59995  WOW! $698 Shipped 50" VIZIO LED Ultra HD 120Hz...
# 59996  Looking for the coolest party to watch #SuperB...
# 59997  Hey football fans, take the #HGTV poll to vote...
# 59998  We added the hashlink http://t.co/Fr3pZKr1XJ t...
# 59999  @SoftStarShoes is giving away free moccasins i...
# 60000  What do @jimmyfallon and I have in common? We ...
#
# [60001 rows x 2 columns]

# %%
# Filter out tweets by appropriate location data
reduced_data = reduce_by_location(all_data)
reduced_data
# Out:
#                       location  \
# 9                   Boston, MA
# 13                     Seattle
# 35            West Seattle, Wa
# 37            West Seattle, Wa
# 72             Boston, MA, USA
# 79       Central Massachusetts
# 116             Massachusetts
# 156                Seattle, WA
# 157                Seattle, WA
# 164             Massachusetts
# 165             Massachusetts
# 175                Seattle, WA
# 176                Seattle, WA
# 177                Seattle, WA
# 198                Seattle, WA
# 199                Seattle, WA
# 200                Seattle, WA
# 201                Seattle, WA
# 209                Seattle, WA
# 210                Seattle, WA
# 211                Seattle, WA
# 226                Seattle, WA
# 227                Seattle, WA
# 228                Seattle, WA
# 229                Seattle, WA
# 236                Seattle, WA
# 237                Seattle, WA
# 238                Seattle, WA
# 239                Seattle, WA
# 253     Seattle, Wasington USA
# ...                        ...
# 59661      Seattle, Washington
# 59676               Boston, MA
# 59693       Canton & Boston MA
# 59694            Massachusetts
# 59704     Brooklyn and Seattle
# 59706                  Seattle
# 59707      Seattle, Washington
# 59726               Boston, MA
# 59730  Suburbia, Massachusetts
# 59755                   Boston
# 59767                   Boston
# 59769           Boston, Mass.
# 59781     Boston & New Orleans
# 59786               Boston, MA
# 59791               Boston, MA
# 59807              Seattle, WA
# 59836              Seattle, WA
# 59850      Seattle, Washington
# 59862     Acton, Boston, World
# 59864              Seattle, Wa
# 59876            Boston MA USA
# 59878              Seattle, WA
# 59888               Boston, MA
# 59897                  Seattle
# 59924             Seattle, WA
# 59934           Massachusetts
# 59944               Boston, MA
# 59947               Boston, MA
# 59959               Boston, MA
# 59989              Seattle, WA
#
#                                                    tweet
# 9      Our @ButchStearns talked #Patriots w/3X #Super...
# 13     #MondayMotivation #GOHAWKS #SEAHAWKS #superbow...
# 35     @DougBaldwinJr just this #mediocre #SuperBowlC...
# 37     Just a #SuperBowlChampion  #Pedestrian wide re...
# 72     @jc_nogales Sunday February 1st. Se juega en A...
# 79     @Deadspin Is it worse than #NFL with #Patriots...
# 116    @katyperry You have to play your "Lose Your Lo...
# 156    Seattle #Seahawks #LegionofBoom Youth Tee #Sup...
# 157    Seattle #Seahawks #LegionofBoom Youth Tee #Sup...
# 164    @JessicCarpenter thanks for the follow Go #Pat...
# 165    @spirocks thanks for the follow Go #Patriots #...
# 175    Marshawn #Lynch #BeastMode Seattle #Seahawks Y...
# 176    Marshawn #Lynch #BeastMode Seattle #Seahawks Y...
# 177    Seattle #Seahawks #12thMan Youth Tee #SuperBow...
# 198    Kam #Chancellor #killakam Seattle #Seahawks Yo...
# 199    Kam #Chancellor #killakam Seattle #Seahawks Yo...
# 200    Seattle #Seahawks #Can'tHoldUs Youth Tee #Supe...
# 201    Seattle #Seahawks #Can'tHoldUs Youth Tee #Supe...
# 209    Seattle #Seahawks #12thman Hoodie #SuperBowlXL...
# 210    Seattle #Seahawks #LegionofBoom Youth Tee #Sup...
# 211    Seattle #Seahawks #LegionofBoom Youth Tee #Sup...
# 226    Seattle #Seahawks #KillaKam #Chancellor Hoodie...
# 227    Seattle #Seahawks #KillaKam #Chancellor Hoodie...
# 228    Marshawn #Lynch #BeastMode Seattle #Seahawks Y...
# 229    Marshawn #Lynch #BeastMode Seattle #Seahawks Y...
# 236    Seattle #Seahawks #Can'tHoldUs Hoodie #SuperBo...
# 237    Seattle #Seahawks #Can'tHoldUs Hoodie #SuperBo...
# 238    Kam #Chancellor #killakam Seattle #Seahawks Yo...
# 239    Kam #Chancellor #killakam Seattle #Seahawks Yo...
# 253    Best way to get to the game in style and luxur...
# ...                                                  ...
# 59661  Fans told @barbershop206 they'd offer up finge...
# 59676  Deflate-gate cookies at Boston Common Coffee. ...
# 59693  Funny Superbowl Pic.\n#Patriots #Superbowl #Li...
# 59694  Media day at @SuperBowl should be fun for the ...
# 59704  Wilson! RT @NFL_AM: Who has the edge in #Super...
# 59706  ICYMI: This guy will be the #SuperBowlXLIX ref...
# 59707  ICYMI: This guy will be the #SuperBowlXLIX ref...
# 59726  #Patriots #PatriotsNation #DeflateGate #SuperB...
# 59730  This #DeflateGate only hurts the @Seahawks bec...
# 59755  I'd trade a 1st round pick for another Lombard...
# 59767  “@Toucherandrich: @bkravitz says #Patriots sho...
# 59769  We're getting another day closer to #SuperBowl...
# 59781  Oh, those Pats. Those dirty, dirty Pats. #defl...
# 59786  There was less outrage for child abuse, rape, ...
# 59791  Guide to American Football: Patriots vs Seahaw...
# 59807  One week from today I'll be on my way to AZ #S...
# 59836  Can't resist this parody of "Blank Space" to c...
# 59850  We are super excited for the #Seahawks to go t...
# 59862  Will anybody do a #DeflateGate ad for #SuperBo...
# 59864  How is it that @nfl can allow a cheater to go ...
# 59876  #Patriots should come out to Taylor Swift's Sh...
# 59878  Might as well have #LanceArmstrong give the pr...
# 59888  Analysis: #Patriots appear to be in a Super me...
# 59897  Microsoft says Go Hawks! #Bellevue #12thMan #S...
# 59924  RT @Seattle_Tourism: BIG NEWS for #Seattle @Se...
# 59934  @AdamSchefter  @ProFootballTalk  @MikeCareyRef...
# 59944  Seahawks Marshawn Lynch picked up 110 yds afte...
# 59947  Just went to text @rainasc and read this text ...
# 59959  If 95% of the country is mad about #DeflateGat...
# 59989  Looking for a great winter hike to do in the #...
#
# [3301 rows x 2 columns]

# %%
# Create target label
# 0: MA 1: WA
all_targets = map_locations(reduced_data)
all_targets
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
# Balance datset
data, train_targets = balance_datasets(reduced_data, all_targets)

# %%
# # Vectorize tweets
vectorizer = CountVectorizer(analyzer='word', stop_words='english', tokenizer=tokenize)
tfidf_transformer = TfidfTransformer()
train_counts = vectorizer.fit_transform(data.tweet)
train_tfidf = tfidf_transformer.fit_transform(train_counts)

# %%
# Truncate twitter data to 50 features
svd = TruncatedSVD(n_components=50, random_state=42)
train_reduced = svd.fit_transform(train_tfidf)

# %%
# Feature Scaling For Certain Algorithms Require Nonnegative Values
min_max_scaler = preprocessing.MinMaxScaler()
train_data = min_max_scaler.fit_transform(train_reduced)

# %%
k=5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
def test_naivebayes():
    # Perform 5-Fold CV to fit Naive Bayes Model

    accuracies = 0
    for train_index, test_index in kf.split(train_data):
        X_train, X_test = train_data[train_index], train_data[test_index]
        y_train, y_test = train_targets[train_index], train_targets[test_index]

        clf = MultinomialNB().fit(X_train, y_train)
        predicted_bayes = clf.predict(X_test)
        accuracy_bayes = np.mean(predicted_bayes == y_test)
        accuracies += accuracy_bayes

    print("Average CV-Accuracy of Multinomial Naive Bayes: " + str(accuracies/k))
    print(classification_report(y_test, predicted_bayes))
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, predicted_bayes))

# %%
def test_logreg():
    # Perform 5-Fold CV to fit Logistic Regression
    
    accuracies = 0
    for train_index, test_index in kf.split(train_data):
        X_train, X_test = train_data[train_index], train_data[test_index]
        y_train, y_test = train_targets[train_index], train_targets[test_index]

        logit = sk.LogisticRegression().fit(X_train, y_train)
        probabilities = logit.predict(X_test)
        predicted_lr = (probabilities > 0.5).astype(int)
        accuracy_lr = np.mean(predicted_lr == y_test)
        accuracies += accuracy_lr

    print("Average CV-Accuracy of Logistic Regression: " + str(accuracies/k))
    print(classification_report(y_test, predicted_lr))
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, predicted_lr))

# %%
def test_svm():
    # Perform 5-Fold CV to fit Logistic Regression
    
    accuracies = 0
    for train_index, test_index in kf.split(train_data):
        X_train, X_test = train_data[train_index], train_data[test_index]
        y_train, y_test = train_targets[train_index], train_targets[test_index]

        linear_SVM = LinearSVC(dual=False, random_state=42).fit(X_train, y_train)
        predicted_svm = linear_SVM.predict(X_test)
        accuracy_svm = np.mean(predicted_svm == y_test)
        accuracies += accuracy_svm

    print("Average CV-Accuracy of Linear SVM: " + str(accuracies/k))
    print(classification_report(y_test, predicted_svm))
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, predicted_svm))

# %%
print("The Comparisions are shown below\n\n")
test_naivebayes()
test_logreg()
test_svm()
# Out:
# The Comparisions are shown below
#
#
# Average CV-Accuracy of Multinomial Naive Bayes: 0.876046511627907
#              precision    recall  f1-score   support
#
#           0       0.88      0.93      0.91       431
#           1       0.92      0.88      0.90       429
#
# avg / total       0.90      0.90      0.90       860
#
# Confusion Matrix:
# [[400  31]
#  [ 52 377]]
# Average CV-Accuracy of Logistic Regression: 0.9225581395348836
#              precision    recall  f1-score   support
#
#           0       0.91      0.94      0.92       431
#           1       0.94      0.90      0.92       429
#
# avg / total       0.92      0.92      0.92       860
#
# Confusion Matrix:
# [[405  26]
#  [ 41 388]]
# Average CV-Accuracy of Linear SVM: 0.9218604651162791
#              precision    recall  f1-score   support
#
#           0       0.92      0.93      0.92       431
#           1       0.92      0.92      0.92       429
#
# avg / total       0.92      0.92      0.92       860
#
# Confusion Matrix:
# [[399  32]
#  [ 36 393]]
